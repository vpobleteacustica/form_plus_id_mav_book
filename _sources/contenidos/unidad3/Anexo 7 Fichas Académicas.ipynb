# %% [markdown]
# # ANEXO 7:	FICHA ACADÉMICA:
#
# ## _Listado de Fichas de Académicos._
#
# <table align="left" style="width:100%">
#     <tbody style="font-size: 14px";>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <td style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">Ingrese información de cada uno de los integrantes del cuerpo académico.</div><br>
#             </td>
#         </tr>
# </tbody>
# </table>
# <br>
# <br>
#
# ### CLAUSTRO
#
# <table align="left" style="width:100%">
#    <tbody style="font-size: 14px";>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="1" colspan="1" width=170><div style="text-align: justify; ">                       Nombre del académico</div><br>
#             </th>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       JORGE ARENAS BERMÚDEZ</div><br>
#             </th>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Carácter del vínculo (claustro/núcleo, colaborador o visitante)</div><br>
#             </th>
#             <td style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Claustro</div><br>
#             </td>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Título profesional, institución, país</div><br>
#             </th>
#             <td style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Ingeniero Acústico, Universidad Austral de Chile, 1989, Chile</div><br>
#             </td>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Grado académico máximo (especificar área disciplinar), institución, año de graduación y                       país</div><br>
#             </th>
#             <td style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Magíster en Física, Universidad Austral de Chile, 1996, Chile<br><br>
#                 Doctor en Ingeniería Mecánica, Auburn University, 2001, Estados Unidos.</div><br>
#             </td>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Línea(s) de investigación</div><br>
#             </th>
#             <td style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Acústica<br><br> Vibraciones<br><br> Acústica: acústica ambiental, comportamiento de                         materiales acústicos, modelamiento acústico.<br><br>
#                 Vibraciones: comportamiento y propiedades vibratorias de materiales y diseño mecánico-                       vibratorio de materiales.</div><br>
#             </td>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <th style="outline: thin solid" rowspan="3" colspan="1"><div style="text-align: justify; ">                       Tesis de magíster dirigidas en los últimos 10 años (finalizadas)</div><br>
#             </th>
#             <th style="outline: thin solid" rowspan="1" colspan="1"><div style="text-align: justify; ">                       Como guía de tesis</div><br>
#             </th>
#         </tr>
#         <tr>
#             <td style="width: 7px;background:#036ED1;"></td>
#             <td>
#                <table align="left" style="width:100%">
#                <tbody style="font-size: 14px";>
#                   <tr>
#                      <td style="width: 1px;background:#FFFFFF;"></td>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Nº</div>
#                      </th>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Año</div>
#                      </th>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Autor</div>
#                      </th>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Título de la Tesis</div>
#                      </th>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Nombre del programa</div>
#                      </th>
#                      <th style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Institución</div>
#                      </th>
#                   </tr>
#                   <tr>
#                      <td style="width: 1px;background:#FFFFFF;"></td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">1</div>
#                      </td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">2019</div>
#                      </td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: center; ">Verónica Marín Bley</div>
#                      </td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: justify; ">Estudio de un dispositivo acústico bi-membrana                              para la absorción de frecuencias bajas</div>
#                      </td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: justify; ">Magíster en Acústica y Vibraciones</div>
#                      </td>
#                      <td style="outline: thin solid" rowspan="1" colspan="1">
#                          <div style="text-align: justify; ">Universidad Austral de Chile</div>
#                      </td>
#                   </tr>
#                 </tbody>
#                 </table>
#             </td>
#         </tr>
# </tbody>
# </table>
